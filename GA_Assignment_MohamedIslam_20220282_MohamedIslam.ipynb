# %% [markdown]
# 1: Define Terms

# %%
import random
import string

# Required definitions
POP_SIZE = 500
MUT_RATE = 0.1
TARGET = "computational cognitive science"
GENES = 'abcdefghijklmnopqrstuvwxyz '

# %% [markdown]
# 2: Initialization

# %%
def initialize_population():
    """Create initial random population"""
    population = [''.join(random.choice(GENES) for _ in range(len(TARGET)))
                 for _ in range(POP_SIZE)]
    print("\n Initial Population Samples:")
    for i in range(3):
        print(f"{i+1}. '{population[i]}'")
    return population

# %% [markdown]
# 3: Selection (Top 50%)

# %%
def select_parents(population):
    """Return top 50% of population sorted by fitness"""
    return sorted(population, key=calculate_fitness, reverse=True)[:POP_SIZE//2]

# %% [markdown]
# 4: Fitness Calculation

# %%
def calculate_fitness(chromosome):
    """Count exact character matches with TARGET"""
    return sum(1 for c, t in zip(chromosome, TARGET) if c == t)

# %% [markdown]
# 5: Crossover

# %%
def crossover(parents):
    """Create offspring through single-point crossover"""
    offspring = []
    while len(offspring) < (POP_SIZE - len(parents)):
        p1, p2 = random.choices(parents, k=2)
        point = random.randint(1, len(TARGET)-1)
        offspring.append(p1[:point] + p2[point:])
    return offspring

# %% [markdown]
# 6: Mutation

# %%
def mutate(offspring):
    """Apply mutations to offspring"""
    mutated = []
    for child in offspring:
        mutated_child = ''.join(
            random.choice(GENES) if random.random() < MUT_RATE else char
            for char in child
        )
        mutated.append(mutated_child)
    print(f"\n Mutated {len(mutated)} offspring")
    print(f"Sample mutation: '{mutated[0]}'")
    return mutated

# %% [markdown]
# 7: Replacement

# %%
def replace_population(parents, offspring):
    """Combine best parents and new offspring"""
    return (parents + offspring)[:POP_SIZE]

# %% [markdown]
# 8: Main Function

# %%
def genetic_algorithm():
    population = initialize_population()
    generation = 0

    while True:
        current_best = max(population, key=calculate_fitness)
        current_fitness = calculate_fitness(current_best)

        # Display progress every 5 generations
        if generation % 5 == 0:
            print(f"\n= Generation {generation} =")
            print(f" Best: '{current_best}'")
            print(f" Matches: {current_fitness}/{len(TARGET)}")

        # Termination condition
        if current_best == TARGET:
            print(f"\n Success in {generation} generations!")
            print(f"Final solution: '{current_best}'")
            return

        # Genetic operations
        parents = select_parents(population)
        offspring = crossover(parents)
        mutated_offspring = mutate(offspring)
        population = replace_population(parents, mutated_offspring)

        generation += 1
        if generation > 200:  # Safety stop
            print("\n⏱ Maximum generations reached")
            return

# Run the algorithm
print("\nStarting evolution...")
genetic_algorithm()
# Out:
# Starting evolution...
#
#  Initial Population Samples:
# 1. 'qvgoxyvimepo wmybnunwdjcdgrl uc'
# 2. 'uvtgnhkfps sn ltzrdebnzfvogkphu'
# 3. 'qqpu sdzsqzfduzqpjkjeaowaadp kp'
#
# = Generation 0 =
#  Best: 'sjkputgbbmxwjdffgqadidz fxvczum'
#  Matches: 6/31
#
#  Mutated 250 offspring
# Sample mutation: 'uvtgnhkfps sn ltzrdtpbszrotijss'
#
#  Mutated 250 offspring
# Sample mutation: 'xzcdurd pqp felapxrowxhhfhptz j'
#
#  Mutated 250 offspring
# Sample mutation: ' lmiufxqaetepslsancddeomvciby e'
#
#  Mutated 250 offspring
# Sample mutation: 'm mtazdbtygrpzlsaniddeomvciby e'
#
#  Mutated 250 offspring
# Sample mutation: 'buanzkajxrpmpteigjmavnm ygjzhuz'
#
# = Generation 5 =
#  Best: 's znoyanifnjz libphtilawsyksnce'
#  Matches: 10/31
#
#  Mutated 250 offspring
# Sample mutation: 'yalg walm aai kiabiayhjnkpnhvld'
#
#  Mutated 250 offspring
# Sample mutation: 'buapzkalmbaau omabiayhjnkpnmnie'
#
#  Mutated 250 offspring
# Sample mutation: 'cazbyjqjerkylbzkvwczilbwsnclncx'
#
#  Mutated 250 offspring
# Sample mutation: 'h plijxdifngjqhzyultiyehunlhncx'
#
#  Mutated 250 offspring
# Sample mutation: 'h rrijpgifijz iitoitnvpmvvgpnep'
#
# = Generation 10 =
#  Best: 'cbbjuubei gkl o qqctpre smiencx'
#  Matches: 13/31
#
#  Mutated 250 offspring
# Sample mutation: 'ojppvbet jnrywwkytwmjhehuncencj'
#
#  Mutated 250 offspring
# Sample mutation: 'eoqhhpskubnqy uvgnjoisa pcgqncx'
#
#  Mutated 250 offspring
# Sample mutation: 'h mourafx cwh l qqctpre sviencx'
#
#  Mutated 250 offspring
# Sample mutation: 'pvwpsnunsapsp xxmniddeovrcnunce'
#
#  Mutated 250 offspring
# Sample mutation: 'sjwpuqgbimnjz dngultiyehdkcency'
#
# = Generation 15 =
#  Best: 'dhmputanifnjz  ib hzxve hvience'
#  Matches: 16/31
#
#  Mutated 250 offspring
# Sample mutation: 'ccqzhpclcbnalzav wqgiyerumgencc'
#
#  Mutated 250 offspring
# Sample mutation: 'dimpungvivnjvgoiyzltezeayeeefco'
#
#  Mutated 250 offspring
# Sample mutation: 'thmputanihnjz iynpithue smvercr'
#
#  Mutated 250 offspring
# Sample mutation: 'r msutabifnjz kfboigcvbjsmicncx'
#
#  Mutated 250 offspring
# Sample mutation: 'huvputasikn z digtukkeevsmmenec'
#
# = Generation 20 =
#  Best: 'dhmpotgtirnljidigeieire sciencx'
#  Matches: 17/31
#
#  Mutated 250 offspring
# Sample mutation: 'cnzyutaaifnji w jqgsiwe svience'
#
#  Mutated 250 offspring
# Sample mutation: 'dhmputagihnvz mcvnytsiewaurvnce'
#
#  Mutated 250 offspring
# Sample mutation: 'ejeputboibnap wmgeircvf ncoenct'
#
#  Mutated 250 offspring
# Sample mutation: 'dhmputanifnjq digeytovf hcolnct'
#
#  Mutated 250 offspring
# Sample mutation: 'zhmputaxifnyzrvoflctilahsfiennc'
#
# = Generation 25 =
#  Best: 'domputanibnau woupztqro sdience'
#  Matches: 19/31
#
#  Mutated 250 offspring
# Sample mutation: 'dnmputenjhnjm libeit qemsviendm'
#
#  Mutated 250 offspring
# Sample mutation: 'computanifnjq uogeikioe ssihucx'
#
#  Mutated 250 offspring
# Sample mutation: 'computaniznjq  rjshtzve zcikncx'
#
#  Mutated 250 offspring
# Sample mutation: 'iomputarrenylkcognztiqfyocience'
#
#  Mutated 250 offspring
# Sample mutation: 'dtmputgtitnjayoounkiizejshienke'
#
# = Generation 30 =
#  Best: 'compufaazosalkcognltiabyocience'
#  Matches: 21/31
#
#  Mutated 250 offspring
# Sample mutation: 'dpmpueanienjk cogh  isahsmiezcu'
#
#  Mutated 250 offspring
# Sample mutation: 'dhmputanivdjl wzzshtiye sciencl'
#
#  Mutated 250 offspring
# Sample mutation: 'pompuhanixnze  im repre sciense'
#
#  Mutated 250 offspring
# Sample mutation: 'drkputatignnl doypwsgabyocience'
#
#  Mutated 250 offspring
# Sample mutation: 'computdtiqeal jogeikiae s i ncl'
#
# = Generation 35 =
#  Best: 'ctmputanifnylkcognutire sciencl'
#  Matches: 23/31
#
#  Mutated 250 offspring
# Sample mutation: 'aomputaniqnaq pogeikivewumience'
#
#  Mutated 250 offspring
# Sample mutation: 'cdmputanihnal  cmupeire scienge'
#
#  Mutated 250 offspring
# Sample mutation: 'comdctacisndlwdoupdtire sciencl'
#
#  Mutated 250 offspring
# Sample mutation: 'docputanioiyl cohnutime oc exce'
#
#  Mutated 250 offspring
# Sample mutation: 'compbfaaxosaakcggnavire sciepcl'
#
# = Generation 40 =
#  Best: 'ctmputanifnylkcognutire sciencl'
#  Matches: 23/31
#
#  Mutated 250 offspring
# Sample mutation: 'ohmputarignrlkcogqotipe s i nce'
#
#  Mutated 250 offspring
# Sample mutation: 'ctmhutatifyylkcmgnutiavxocienpx'
#
#  Mutated 250 offspring
# Sample mutation: 'cofputatmtfalncnceikjzx sqiencl'
#
#  Mutated 250 offspring
# Sample mutation: 'computatianclkcogntcige scijncl'
#
#  Mutated 250 offspring
# Sample mutation: 'c hkucanion p gogkutice srvunce'
#
# = Generation 45 =
#  Best: 'computanionbp cogeirire science'
#  Matches: 25/31
#
#  Mutated 250 offspring
# Sample mutation: 'compucacisnalz omlieike fcience'
#
#  Mutated 250 offspring
# Sample mutation: 'comeutatifnpl nmgnztige sjiencq'
#
#  Mutated 250 offspring
# Sample mutation: 'compjtatffnalkcornttioe spiencx'
#
#  Mutated 250 offspring
# Sample mutation: 'cowputatiunyo cognmoire scibnce'
#
#  Mutated 250 offspring
# Sample mutation: 'comzutatihnjlbwojpityvewsciunce'
#
# = Generation 50 =
#  Best: 'compujatignal cognutire sciencl'
#  Matches: 26/31
#
#  Mutated 250 offspring
# Sample mutation: 'coepctanitlbp cxgnttvr  bcienex'
#
#  Mutated 250 offspring
# Sample mutation: 'bomputgtiwnkl s geivore scimnce'
#
#  Mutated 250 offspring
# Sample mutation: 'mxmputatihczlbwobeirire wcience'
#
#  Mutated 250 offspring
# Sample mutation: 'computauiunylkicgnutiyk scsynme'
#
#  Mutated 250 offspring
# Sample mutation: 'compttatifngl cognutl ersciensf'
#
# = Generation 55 =
#  Best: 'compujatignal cognutire sciencl'
#  Matches: 26/31
#
#  Mutated 250 offspring
# Sample mutation: 'compwtanivnal goggaeiaefcczence'
#
#  Mutated 250 offspring
# Sample mutation: 'cymputznivnal wogridire sciencl'
#
#  Mutated 250 offspring
# Sample mutation: 'computgtitndl cpgnutitbyscienje'
#
#  Mutated 250 offspring
# Sample mutation: 'cxmputativnajswognztibe scieqcg'
#
#  Mutated 250 offspring
# Sample mutation: 'cqmputktqeaqlkcognttioetscienle'
#
# = Generation 60 =
#  Best: 'compujatignal cognutire sciencl'
#  Matches: 26/31
#
#  Mutated 250 offspring
# Sample mutation: 'c mputatiznhxkcogltbirelicience'
#
#  Mutated 250 offspring
# Sample mutation: 'computationyl cogdiyibxwvcienco'
#
#  Mutated 250 offspring
# Sample mutation: 'comdutttiznclkcogntcioe science'
#
#  Mutated 250 offspring
# Sample mutation: 'computsiifngl cognuti e swienck'
#
#  Mutated 250 offspring
# Sample mutation: 'cimpubajignalfcoglutioe scienct'
#
# = Generation 65 =
#  Best: 'computationzp cognutire science'
#  Matches: 27/31
#
#  Mutated 250 offspring
# Sample mutation: 'compbfatiinav cogkwtigkzsqience'
#
#  Mutated 250 offspring
# Sample mutation: 'compubatigeal cognutioe sciengp'
#
#  Mutated 250 offspring
# Sample mutation: 'compjtatifngl cognzhnre sciewce'
#
#  Mutated 250 offspring
# Sample mutation: 'computatiqnalxcopjutive scibncl'
#
#  Mutated 250 offspring
# Sample mutation: 'chdtttakignylkcognotiro science'
#
# = Generation 70 =
#  Best: 'computativnalacognitcve science'
#  Matches: 28/31
#
#  Mutated 250 offspring
# Sample mutation: ' ompudztiunkl cognttiaeosciencl'
#
#  Mutated 250 offspring
# Sample mutation: 'computatiznclk ognttire science'
#
#  Mutated 250 offspring
# Sample mutation: 'computatizntlwchanmtire science'
#
#  Mutated 250 offspring
# Sample mutation: 'compuratignal cognttirn sciench'
#
#  Mutated 250 offspring
# Sample mutation: 'cemputatignalrcognitcve sbience'
#
# = Generation 75 =
#  Best: 'computativnalacognitcve science'
#  Matches: 28/31
#
#  Mutated 250 offspring
# Sample mutation: 'comwutanignalscoznftian sciegce'
#
#  Mutated 250 offspring
# Sample mutation: 'cmmpgta ssncd cognutize sciznce'
#
#  Mutated 250 offspring
# Sample mutation: 'commutapionzp cognftiwe sci nce'
#
#  Mutated 250 offspring
# Sample mutation: 'compttatiknalfcognutire scienre'
#
#  Mutated 250 offspring
# Sample mutation: 'cojputatpknal jogpxtijefscience'
#
# = Generation 80 =
#  Best: 'computationpl cognitivetscience'
#  Matches: 29/31
#
#  Mutated 250 offspring
# Sample mutation: 'computatignalycogndtyve sciesce'
#
#  Mutated 250 offspring
# Sample mutation: 'computatignalyclgndtive ncience'
#
#  Mutated 250 offspring
# Sample mutation: 'yomputatignalycogndtive ncience'
#
#  Mutated 250 offspring
# Sample mutation: 'compuoetigeal pognutioe science'
#
#  Mutated 250 offspring
# Sample mutation: 'compukatihnal cognutite science'
#
# = Generation 85 =
#  Best: 'computationpl cognitivetscience'
#  Matches: 29/31
#
#  Mutated 250 offspring
# Sample mutation: 'computatirn l cognutigz scifnce'
#
#  Mutated 250 offspring
# Sample mutation: 'compqtdticnal cdvhitige jcience'
#
#  Mutated 250 offspring
# Sample mutation: 'colputitignax cogniuire science'
#
#  Mutated 250 offspring
# Sample mutation: 'compctational cogaiqfre vqizace'
#
#  Mutated 250 offspring
# Sample mutation: 'computatrvtalxcognutije sctence'
#
# = Generation 90 =
#  Best: 'computational cognittve science'
#  Matches: 30/31
#
#  Mutated 250 offspring
# Sample mutation: 'comkutahional cogsutise science'
#
#  Mutated 250 offspring
# Sample mutation: 'cqmfutational coqniqive sqience'
#
#  Mutated 250 offspring
# Sample mutation: 'comwutatiotdl cygndtive dcience'
#
#  Mutated 250 offspring
# Sample mutation: 'computatignal qpgnitiie scienke'
#
#  Mutated 250 offspring
# Sample mutation: 'comgutarionzi cognftiwl science'
#
# = Generation 95 =
#  Best: 'computational cognittve science'
#  Matches: 30/31
#
#  Mutated 250 offspring
# Sample mutation: 'computatignal cognutioe skiente'
#
#  Mutated 250 offspring
# Sample mutation: 'computptconzl cornbtike sceence'
#
#  Mutated 250 offspring
# Sample mutation: 'cvmputational cognitqve qcience'
#
#  Mutated 250 offspring
# Sample mutation: 'cqmputationzp cognitzve sxienne'
#
#  Mutated 250 offspring
# Sample mutation: 'cgmputctionaz crgeiyiqe science'
#
# = Generation 100 =
#  Best: 'computational cognittve science'
#  Matches: 30/31
#
#  Mutated 250 offspring
# Sample mutation: 'coeputatinncl cognitive scixncy'
#
#  Mutated 250 offspring
# Sample mutation: 'comouthtiozaw cogniziveksccens '
#
#  Mutated 250 offspring
# Sample mutation: 'computativnalacvgnitcve science'
#
#  Mutated 250 offspring
# Sample mutation: 'computatiznal cognitcvj  cience'
#
#  Mutated 250 offspring
# Sample mutation: 'computationah cognitcve science'
#
# = Generation 105 =
#  Best: 'computational cognittve science'
#  Matches: 30/31
#
#  Mutated 250 offspring
# Sample mutation: 'computatlojal cognjtive aciewce'
#
#  Mutated 250 offspring
# Sample mutation: 'computazionml coghizive sciencj'
#
#  Mutated 250 offspring
# Sample mutation: 'kodpuwatimnalfcognitive fciency'
#
#  Mutated 250 offspring
# Sample mutation: 'nompukateonal cmgeitcvewscience'
#
#  Mutated 250 offspring
# Sample mutation: 'computationll ztgnatiwe scienke'
#
# = Generation 110 =
#  Best: 'computational cognitive science'
#  Matches: 31/31
#
#  Success in 110 generations!
# Final solution: 'computational cognitive science'
